# %%
import pandas as pd

# %%
df = pd.read_csv('sensor_sample_data.csv')

# %%
df.columns
# Out:
# Index(['EVENTTIME', 'HARDWARENAME', 'IDNODECHIPTEMPARATURE', 'txPOWER1',
#        'txPOWER2', 'txPOWER3', 'txPOWER4', 'txPOWER5', 'rssi1', 'rssi2',
#        'rssi3', 'rssi4', 'rssi5'],
#       dtype='str')
